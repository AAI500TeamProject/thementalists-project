# %%
from IPython.display import display
from google.colab import drive
import pandas as pd
from sklearn import preprocessing

# %%
# prompt: add a radio widget so I can choose between colab or local datset import and default to local

dataset_source = 'Colab' #@param ["Colab", "Local"]

if dataset_source == 'Colab':
  print("Importing from Colab")
  drive.mount('/content/drive')
  df1 = pd.read_csv('/content/drive/MyDrive/AAI50 Project/Dataset/thementalists-project/Dataset/MentalHealth/1-mental-illnesses-prevalence.csv')
  df2 = pd.read_csv('/content/drive/MyDrive/AAI50 Project/Dataset/thementalists-project/Dataset/MentalHealth/2-burden-disease-from-each-mental-illness.csv')
  df3 = pd.read_csv('/content/drive/MyDrive/AAI50 Project/Dataset/thementalists-project/Dataset/MentalHealth/3-adult-population-covered-in-primary-data-on-the-prevalence-of-major-depression.csv')
  df4 = pd.read_csv('/content/drive/MyDrive/AAI50 Project/Dataset/thementalists-project/Dataset/MentalHealth/4-adult-population-covered-in-primary-data-on-the-prevalence-of-mental-illnesses.csv')
  df5 = pd.read_csv('/content/drive/MyDrive/AAI50 Project/Dataset/thementalists-project/Dataset/MentalHealth/5-anxiety-disorders-treatment-gap.csv')
  df6 = pd.read_csv('/content/drive/MyDrive/AAI50 Project/Dataset/thementalists-project/Dataset/MentalHealth/6-depressive-symptoms-across-us-population.csv')
  df7 = pd.read_csv('/content/drive/MyDrive/AAI50 Project/Dataset/thementalists-project/Dataset/MentalHealth/7-number-of-countries-with-primary-data-on-prevalence-of-mental-illnesses-in-the-global-burden-of-disease-study.csv')
  # Add your Colab import code here
else:
  print("Importing from Local")
  # Add your local import code here
  df1 = pd.read_csv('1-mental-illnesses-prevalence.csv')
# Out:
# Importing from Colab
# Mounted at /content/drive

# %%
df1.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# ...

# %%
df1_column_names = list(df1.columns.values)
df1_column_names
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Eating disorders (share of population) - Sex: Both - Age: Age-standardized']

# %%
df1 = df1.rename(columns={'Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized': 'Schizophrenia disorders',
                          'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized': 'Depressive disorders',
                         'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized':'Anxiety disorders',
                         'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized':'Bipolar disorders',
                         'Eating disorders (share of population) - Sex: Both - Age: Age-standardized':'Eating disorders'})

# %%
df1_variables = df1[["Schizophrenia disorders","Depressive disorders","Anxiety disorders","Bipolar disorders",
                       "Eating disorders"]]

# %%
features = ['Schizophrenia disorders', 'Depressive disorders','Anxiety disorders','Bipolar disorders']
X_model = df1[features]
y_model = df1["Eating disorders"]

# %%
scaler = preprocessing.MinMaxScaler()
X_model_norm = scaler.fit_transform(X_model)

# %%
#We will implement one hot encoding
m_ill_enc = pd.get_dummies(df1, columns = ['Entity', 'Year'], prefix = ['Country','Year'])

# %%
m_ill_enc.head(10)
# Out:
#   Code  Schizophrenia disorders  Depressive disorders  Anxiety disorders  \
# 0  AFG                 0.223206              4.996118           4.713314
# 1  AFG                 0.222454              4.989290           4.702100
# 2  AFG                 0.221751              4.981346           4.683743
# 3  AFG                 0.220987              4.976958           4.673549
# 4  AFG                 0.220183              4.977782           4.670810
# 5  AFG                 0.219409              4.978228           4.668100
# 6  AFG                 0.218465              4.981489           4.665759
# 7  AFG                 0.217286              4.987593           4.665013
# 8  AFG                 0.216074              4.996858           4.668240
# 9  AFG                 0.215068              5.004257           4.673557
#
#    Bipolar disorders  Eating disorders  Country_Afghanistan  \
# 0           0.703023          0.127700                 True
# ...
